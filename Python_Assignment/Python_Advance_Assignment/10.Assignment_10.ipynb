# %%
Q1. What is the difference between __getattr__ and __getattribute__?

Ans:-
    __getattribute__ is used to find a attribute of a class. It raises an AttributeError of it fails to find an attribute
    of a class. __getattr__ is implemented latter if AttributeError is generated by __getattribute__, but for this 
    __getattribute__ and __getattr__ both has to be defined in a same class. If no attribute is found, __getattr__ returns
    a default value. So key difference is that __getattr__ is called for attributes that don't exist on a class

# %% [raw]
# Q2. What is the difference between properties and descriptors?
#
# Ans:-
#     The difference between properties and Descriptors is:
#
#     Properties: With Properties we can bind getter, setter and delete function together with an attribute name, using built
#                 in property function or @property decorator. when we do this, each reference to an attribute looks like
#                 simple, direct access, but involves the appropriate function of the object.
#
#     Description: With Descriptor we can bind getter, setter and delete function into seperate class. we then assign an
#                  object of this class to the attribute name in our main class. When we do this, each reference  to an
#                  attribute looks like a simple, direct access but invokes an appropriate function of descriptor object.

# %% [raw]
# Q3. What are the key differences in functionality between getattr and getattribute, as well as properties and descriptors?
#
# Ans:-
#     The key Differences between __getattr__, __getattribute__, Properties and Descriptors are:
#
#     __getattr__ : Python will call this method whenever you request an attribute that hasn't been already defined
#
#     __getattribute__ : This method will invoked before looking at the actual attributes of the object. Means, if we have
#                        __getattribute__ method in our class, python invokes this method for every attribute regardless
#                        wheather it exist or not.
#
#
#     Properties: With Properties we can bind getter, setter and delete function together with an attribute name, using built
#                 in property function or @property decorator. when we do this, each reference to an attribute looks like
#                 simple, direct access, but involves the appropriate function of the object.
#
#     Description: With Descriptor we can bind getter, setter and delete function into seperate class. we then assign an
#                  object of this class to the attribute name in our main class. When we do this, each reference  to an
#                  attribute looks like a simple, direct access but invokes an appropriate function of descriptor object.
